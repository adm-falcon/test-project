# %%
pip install -U japanmap jupyter matplotlib pandas xlrd
# Out:
# Requirement already up-to-date: japanmap in c:\users\adm-f\anaconda3\lib\site-packages (0.0.21)
# Requirement already up-to-date: jupyter in c:\users\adm-f\anaconda3\lib\site-packages (1.0.0)
# ...
# Requirement already up-to-date: xlrd in c:\users\adm-f\anaconda3\lib\site-packages (1.2.0)
# ...
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.1.2
#     Uninstalling matplotlib-3.1.2:
#       Successfully uninstalled matplotlib-3.1.2
#   Attempting uninstall: pandas
#     Found existing installation: pandas 0.25.3
#     Uninstalling pandas-0.25.3:
#       Successfully uninstalled pandas-0.25.3
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from japanmap import pref_names
from japanmap import pref_code
from japanmap import groups
# %config InlineBackend.figure_formats = {'png', 'retina'}
# %matplotlib inline
import matplotlib.pyplot as plt
from japanmap import picture

# %% [markdown]
# ### 日本地図の表示

# %%
plt.rcParams['figure.figsize'] = 6, 6
plt.imshow(picture());

# %%
# 北海道を青色で塗る
plt.imshow(picture({'北海道': 'blue', '青森県':'red'}));
plt.savefig('japan.png')
